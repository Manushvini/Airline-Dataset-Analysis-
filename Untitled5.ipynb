# %%
 import pandas as pd
 import pickle
 import warnings

 warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("/content/Airline Dataset Updated - v2.csv")
data
# Out:
#       Passenger ID  First Name  Last Name  Gender  Age Nationality  \
# 0           ABVWIg      Edithe     Leggis  Female   62       Japan
# 1           jkXXAX      Elwood       Catt    Male   62   Nicaragua
# 2           CdUz2g       Darby    Felgate    Male   67      Russia
# 3           BRS38V    Dominica       Pyle  Female   71       China
# 4           9kvTLo         Bay    Pencost    Male   21       China
# ...            ...         ...        ...     ...  ...         ...
# 98614       hnGQ62      Gareth    Mugford    Male   85       China
# 98615       2omEzh       Kasey   Benedict  Female   19      Russia
# 98616       VUPiVG      Darrin     Lucken    Male   65   Indonesia
# 98617       E47NtS       Gayle  Lievesley  Female   34       China
# 98618       8JYEcz  Wilhelmine     Touret  Female   10      Poland
#
#                       Airport Name Airport Country Code        Country Name  \
# 0                 Coldfoot Airport                   US       United States
# ...

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data.shape
# Out:
# (98619, 15)

# %%
data.head()
# Out:
#   Passenger ID First Name Last Name  Gender  Age Nationality  \
# 0       ABVWIg     Edithe    Leggis  Female   62       Japan
# 1       jkXXAX     Elwood      Catt    Male   62   Nicaragua
# 2       CdUz2g      Darby   Felgate    Male   67      Russia
# 3       BRS38V   Dominica      Pyle  Female   71       China
# 4       9kvTLo        Bay   Pencost    Male   21       China
#
#                 Airport Name Airport Country Code   Country Name  \
# 0           Coldfoot Airport                   US  United States
# 1          Kugluktuk Airport                   CA         Canada
# 2     Grenoble-Isère Airport                   FR         France
# 3  Ottawa / Gatineau Airport                   CA         Canada
# 4            Gillespie Field                   US  United States
#
#   Airport Continent     Continents Departure Date Arrival Airport  \
# 0               NAM  North America      6/28/2022             CXF
# 1               NAM  North America     12/26/2022             YCO
# ...

# %%
data.tail()
# Out:
#       Passenger ID  First Name  Last Name  Gender  Age Nationality  \
# 98614       hnGQ62      Gareth    Mugford    Male   85       China
# 98615       2omEzh       Kasey   Benedict  Female   19      Russia
# 98616       VUPiVG      Darrin     Lucken    Male   65   Indonesia
# 98617       E47NtS       Gayle  Lievesley  Female   34       China
# 98618       8JYEcz  Wilhelmine     Touret  Female   10      Poland
#
#                       Airport Name Airport Country Code        Country Name  \
# 98614               Hasvik Airport                   NO              Norway
# 98615          Ampampamena Airport                   MG          Madagascar
# 98616  Albacete-Los Llanos Airport                   ES               Spain
# 98617               Gagnoa Airport                   CI       Côte d'Ivoire
# 98618          Yoshkar-Ola Airport                   RU  Russian Federation
#
#       Airport Continent Continents Departure Date Arrival Airport  \
# ...

# %%
data["Nationality"]. unique()
# Out:
# array(['Japan', 'Nicaragua', 'Russia', 'China', 'Brazil', 'Ivory Coast',
#        'Vietnam', 'Palestinian Territory', 'Thailand', 'Tunisia',
#        'Sweden', 'Colombia', 'Greece', 'Philippines', 'Ukraine',
#        'Indonesia', 'Croatia', 'Democratic Republic of the Congo',
#        'France', 'Peru', 'Latvia', 'Germany', 'Czech Republic', 'Ireland',
#        'Iran', 'Madagascar', 'United States', 'Ghana', 'Mali',
#        'Guatemala', 'Kyrgyzstan', 'Haiti', 'Afghanistan', 'Ethiopia',
#        'Tanzania', 'Nigeria', 'Cameroon', 'Morocco', 'Armenia', 'Mexico',
#        'Chile', 'Albania', 'Luxembourg', 'Honduras', 'Portugal',
#        'Kazakhstan', 'Pakistan', 'Poland', 'South Africa', 'Kenya',
#        'Serbia', 'Maldives', 'Argentina', 'Uruguay', 'Netherlands',
#        'Botswana', 'Egypt', 'Syria', 'Myanmar', 'Slovenia', 'Spain',
#        'Macedonia', 'Mongolia', 'Yemen', 'Benin', 'Laos', 'Norway',
#        'Sao Tome and Principe', 'Venezuela', 'United Kingdom', 'Denmark',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98619 entries, 0 to 98618
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Passenger ID          98619 non-null  object
#  1   First Name            98619 non-null  object
#  2   Last Name             98619 non-null  object
#  3   Gender                98619 non-null  object
#  4   Age                   98619 non-null  int64
#  5   Nationality           98619 non-null  object
#  6   Airport Name          98619 non-null  object
#  7   Airport Country Code  98619 non-null  object
#  8   Country Name          98619 non-null  object
#  9   Airport Continent     98619 non-null  object
#  10  Continents            98619 non-null  object
#  11  Departure Date        98619 non-null  object
#  12  Arrival Airport       98619 non-null  object
#  13  Pilot Name            98619 non-null  object
#  14  Flight Status         98619 non-null  object
# ...

# %%
data.groupby(["Age"]).count()
# Out:
#      Passenger ID  First Name  Last Name  Gender  Nationality  Airport Name  \
# Age
# 1            1075        1075       1075    1075         1075          1075
# 2            1058        1058       1058    1058         1058          1058
# 3            1095        1095       1095    1095         1095          1095
# 4            1110        1110       1110    1110         1110          1110
# 5            1082        1082       1082    1082         1082          1082
# ..            ...         ...        ...     ...          ...           ...
# 86           1068        1068       1068    1068         1068          1068
# 87           1064        1064       1064    1064         1064          1064
# 88           1069        1069       1069    1069         1069          1069
# 89           1131        1131       1131    1131         1131          1131
# 90           1076        1076       1076    1076         1076          1076
#
# ...

# %%
data.groupby(["Nationality"]).count()
# Out:
#                    Passenger ID  First Name  Last Name  Gender  Age  \
# Nationality
# Afghanistan                 394         394        394     394  394
# Aland Islands                20          20         20      20   20
# Albania                     445         445        445     445  445
# Algeria                       3           3          3       3    3
# American Samoa               26          26         26      26   26
# ...                         ...         ...        ...     ...  ...
# Wallis and Futuna             8           8          8       8    8
# Western Sahara                5           5          5       5    5
# Yemen                       400         400        400     400  400
# Zambia                       86          86         86      86   86
# Zimbabwe                    104         104        104     104  104
#
#                    Airport Name  Airport Country Code  Country Name  \
# Nationality
# ...

# %%
data["Age"].unique()
# Out:
# array([62, 67, 71, 21, 55, 73, 36, 35, 13, 39, 47, 77, 32, 22, 28, 12, 87,
#        24, 19, 45, 29,  8, 14, 53,  6, 58, 44,  9, 74, 37, 54, 61, 56, 85,
#        50, 83, 17, 76, 51, 16, 23, 41, 52, 33, 89,  3, 30, 26, 78, 43, 80,
#        49, 68, 70, 46, 65,  2,  7, 25, 88, 18,  4, 27, 10, 72, 79, 66, 38,
#        84, 11, 20, 82, 86, 42,  1, 90, 69, 75, 15, 40, 48, 64, 57, 59, 34,
#        81,  5, 63, 31, 60])

# %%
data["Continents"].unique()
# Out:
# array(['North America', 'Europe', 'South America', 'Asia', 'Oceania',
#        'Africa'], dtype=object)
